# %% [markdown]
# <a href="https://colab.research.google.com/github/Esteban191/upgraded-goggles/blob/main/apuestas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_apuestas=pd.read_csv("/content/drive/MyDrive/mauro_apuestas/apuestas-ene-feb-mar-2023-compilado (1).csv")

# %%
df_apuestas.shape
# Out:
# (194, 10)

# %%
df_apuestas
# Out:
#      LIG   CUO                                     PARTIDO      COMBO 1 COM 2  \
# 0    ESP  1.36               Athletic Bilbao - Real Madrid   DOV + -4.5   NaN
# 1    ITA  1.45                         Juventus - Atalanta  H2L + -11.5   NaN
# 2    ITA  1.26                               Spezia - Roma   DOV + -4.5   NaN
# 3    ING  1.62                 Arsenal - Manchester United  DOL + -12.5   NaN
# 4    ESP  1.34                       FC Barcelona - Getafe     GL + 1.5   NaN
# ..   ...   ...                                         ...          ...   ...
# 189  EUR  1.33                      FC Union Berlin - Ajax          DOL   NaN
# 190  EUR  1.38                AS Mónaco - Bayer Leverkusen          DOL   NaN
# 191  LIB  1.45                Cerro Porteño - Curicó Unido           GL   NaN
# 192  LIB  1.40  Sporting Cristal - Nacional Asunción (PAR)          H2V   NaN
# 193  URU  1.32                CA Huracan - CA Boston River           GL   NaN
#
# ...
